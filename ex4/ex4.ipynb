# %%
from IPython.display import display, HTML

fichier = open("ex4.css", "r")
f_css = fichier.read()
fichier.close()
fichier = open("ex4.html", "r")
f_html = fichier.read()
fichier.close()
fichier = open("ex4.js", "r")
f_js = fichier.read()
fichier.close()
f_html = f_html.format(f_css, f_js)
display(HTML(f_html))
# Out:
# <!doctype html>
# <html lang="fr">
# <head>
#   <meta charset="iso-8859-1">
#   <style>
#
# .vert {
#     background-color: darkseagreen;
# }
#
# .rouge {
#     background-color:lightcoral;
# }
#   </style>
# </head>
#
# <body>
#     <p id="para">Some text here</p>
#     <p>
#       <button onclick="changeColor('blue');">blue</button>
#       <button onclick="changeColor('red');">red</button>
#     </p>
#     <p><button class="rouge" id="id_button_connexion">Connexion</button></p>
#     <p><button id="id_button_mesure">Mesure</button></p>
#     <p id="id_resultat"></p>
# </body>
#    <script>
#      var port = null;
#
# function changeColor(newColor) {
#   const elem = document.getElementById("para");
#   elem.style.color = newColor;
# }
#
# async function do_connect() {
# // Prompt user to select any serial port.
# console.log("connexion");
#   if (port == null)  {
#     port = await navigator.serial.requestPort();
#     await port.open({ baudRate: 9600 });
# ...
